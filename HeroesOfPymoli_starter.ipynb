# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
total_players = purchase_data.loc[:,["SN", "Age", "Gender"]]
dropped_total_player = total_players.drop_duplicates()
sum_players = dropped_total_player.count()[0]
pd.DataFrame({"Total Players" : [sum_players]})
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_item = purchase_data["Item ID"].nunique()
total_num_purchases = purchase_data["Purchase ID"].count()
average_price= purchase_data["Price"].mean()
total_rev = purchase_data["Price"].sum()
unique_item,total_num_purchases, average_price, total_rev
purchasing_analysis_tool = pd.DataFrame({"Number of Unique Items" : [unique_item], 
              "Average Price" : [average_price], 
              "Number of Purchases": [total_num_purchases], 
              "Total Revenue": [total_rev] })
purchasing_analysis_tool
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     183       3.050987                  780        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
len_of_data = purchase_data["SN"].nunique()
male=purchase_data.loc[purchase_data['Gender'] == "Male"]["SN"].nunique()
male_percent = ((male/len_of_data)*100)

female=purchase_data.loc[purchase_data['Gender'] == "Female"]["SN"].nunique()
female_percent = ((female/len_of_data)*100)

other= len_of_data - male - female
other_percent = ((other/len_of_data)*100)


Gender_Demographics_summary = pd.DataFrame({"": ["Male", "Female", "Other / Non-Disclosed"],"Total Count": [male,female,other], "Percentage of Players":[male_percent,female_percent, other_percent] })
Gender_Demographics_summary

Gender_Demographics_final= Gender_Demographics_summary.set_index("")
Gender_Demographics_final.style.format({"Percentage of Players": "{:.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_14357a8e_1c82_11ea_b2a4_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14357a8e_1c82_11ea_b2a4_acde48001122level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_14357a8e_1c82_11ea_b2a4_acde48001122row0_col0" class="data row0 col0" >484</td>
#                         <td id="T_14357a8e_1c82_11ea_b2a4_acde48001122row0_col1" class="data row0 col1" >84.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_14357a8e_1c82_11ea_b2a4_acde48001122level0_row1" class="row_heading level0 row1" >Female</th>
# ...

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
len_of_purchase = purchase_data["Purchase ID"].nunique()
avg_purchase_price = purchase_data["Price"].nunique()
#Purchase Count

female_purchase_count=purchase_data.loc[purchase_data['Gender'] == "Female"]["Purchase ID"].nunique()
male_purchase_count=purchase_data.loc[purchase_data['Gender'] == "Male"]["Purchase ID"].nunique()
other_purchase_count = (len_of_purchase - male_purchase_count - female_purchase_count)
#Average Puchase Price

female_avg_purchase_price = purchase_data.loc[purchase_data['Gender'] == "Female"]["Price"].mean()
male_avg_purchase_price = purchase_data.loc[purchase_data['Gender'] == "Male"]["Price"].mean()
other_avg_purchase_price = purchase_data.loc[purchase_data['Gender'] == "Other / Non-Disclosed"]["Price"].mean()

#Total Purchase Value 
female_sum_purchase_price = purchase_data.loc[purchase_data['Gender'] == "Female"]["Price"].sum()
male_sum_purchase_price = purchase_data.loc[purchase_data['Gender'] == "Male"]["Price"].sum()
other_sum_purchase_price = purchase_data.loc[purchase_data['Gender'] == "Other / Non-Disclosed"]["Price"].sum()

#Average Total Purchase per Person
 #avg_female_purchase_count= 
avg_total_female = (female_sum_purchase_price/female)
avg_total_male = (male_sum_purchase_price/male)
avg_other = (other_sum_purchase_price/other)


pd.DataFrame({"Gender": ["Female", "Male", "Other / Non-Disclosed"],"Purchase Count": [female_purchase_count,male_purchase_count,other_purchase_count], 
              "Average Purchase Price":[female_avg_purchase_price,male_avg_purchase_price, other_avg_purchase_price],
              "Total Purchase Value":[female_sum_purchase_price,male_sum_purchase_price,other_sum_purchase_price], 
              "Avg Total Purchase per Person": [avg_total_female,avg_total_male,avg_other]
             })
# Out:
#                   Gender  Purchase Count  Average Purchase Price  \
# 0                 Female             113                3.203009
# 1                   Male             652                3.017853
# 2  Other / Non-Disclosed              15                3.346000
#
#    Total Purchase Value  Avg Total Purchase per Person
# 0                361.94                       4.468395
# 1               1967.64                       4.065372
# 2                 50.19                       4.562727

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
## Establish bins for ages
bins = [-1,9.99,14.99,19.99,24.99,29.99,34.99,39.99,1000]
category =["<10","10-14","15-19","20-24","25-29","30-34","35-39","40 +" ]

#Categorize the existing players using the age bins. Hint: use pd.cut()
purchase_data[""] = pd.cut(purchase_data["Age"],bins, labels=category)
age_grouped = purchase_data.groupby([""])

age_grouped.head()
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 5              5        Yalae81   22                   Male       81
# 6              6      Itheria73   36                   Male      169
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 14            14    Saesrideu94   35                   Male      165
# 19            19      Chamalo71   30                   Male       89
# 22            22   Siarithria38   38  Other / Non-Disclosed       24
# 23            23       Eyrian71   40                   Male      151
# 24            24        Siala43   30                   Male      141
# ...

# %%
bin_count = age_grouped["Age Group"].count()
total_count = age_grouped["SN"].count()
player_percentage = ((bin_count/total_count)*100)

test = pd.DataFrame({"Total Count":[bin_count], 
             "Percentage of Players": [player_percentage]})
test.groupby([""])
test
# Out:
#                                          Total Count  \
# 0
# <10       23
# 10-14     28
# 15-19    136
# 20-24 ...
#
#                                Percentage of Players
# 0
# <10      100.0
# 10-14    100.0
# 15-19    100.0
# ...

# %%
# Out:
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05            $1,114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
purchase_data.loc[purchase_data["SN"]]

# %%
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 108     Extraction, Quickblade Of Trembling Hands                 9
# 82      Nirvana                                                   9
# 19      Pursuit, Cudgel of Necromancy                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 92      Final Critic                                              8
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
